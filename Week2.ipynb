# %% [markdown]
# <a href="https://colab.research.google.com/github/fajarpw/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#Accessing Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/WEEK2/IMAGE/bench.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/WEEK2/IMAGE/stairs_2.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,2024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)
#Tampilkan plot dengan ukuran kanvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#Memberikan koordinat titik pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0), thickness = 10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255), thickness = 15)
plt.imshow(black_img)

# %%
#Menambahkan lingkaran
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0), thickness = 8)
plt.imshow(black_img)

# %%
#Menambahkan garis horizontal
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness = 5)
plt.imshow(black_img)

# %%
#Menambahkan Text
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='HELLO', org=(10,500), fontFace = font, fontScale = 4, color=(255,255,0), thickness = 2, lineType = cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300], [200,200], [400,300], [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #Nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R,G,B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
#Menambahkan Polyline
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0), thickness = 5)
plt.imshow(black_img2)

# %%
#Tugas 1
img_width = img.shape[0]
img_length = img.shape[1]
print('Width (img) = ', img_width)
print('Length (img) = ', img_length)
img5_width = img.shape[0]
img5_length = img.shape[1]
print('-------------------------')
print('Width (img5) = ', img5_width)
print('Length (img5) = ', img5_length)
# Out:
# Width (img) =  413
# Length (img) =  640
# -------------------------
# Width (img5) =  413
# Length (img5) =  640

# %%
#Tugas 2.1
img_rg = img.copy()
img_rg[:,:,0] = 0
plt.imshow(img_rg)

# %%
#Tugas 2.2
img_gb = img.copy()
img_gb[:,:,2] = 0
plt.imshow(img_gb)

# %%
#Tugas 3
img_task3 = img.copy()
task3 = img_task3[10:100,10:100]
plt.imshow(task3)

# %%
#Tugas 4
img_task4 = img.copy()
img_task4[:,:,0] = 0
img_task4[:,:,2] = 0
task4 = img_task4[10:100,:]
plt.imshow(task4)

# %%
#Tugas 5 
import random
new_img5 = cv.imread('/content/drive/MyDrive/PCVK/WEEK2/IMAGE/night.jpg')
img_task5 = cv.cvtColor(new_img5, cv.COLOR_BGR2RGB)
width = new_img5.shape[0]
length = new_img5.shape[1]
print('Width = ', width)
print('Length = ', length)
for  i in range(5):
  cv.rectangle(img_task5, pt1 = (random.randint(0,length),random.randint(0,width)), pt2 = (random.randint(0,length),random.randint(0,width)), color = (255,0,0), thickness = random.randint(5,10))


plt.imshow(img_task5)
# Out:
# Width =  960
# Length =  640

# %%
#Tugas 6
new_img6 = img_task5.copy()
img_task6 = cv.flip(new_img6, 0)
plt.imshow(img_task6)

# %%
#Tugas 7 
new_img7 = cv.imread('/content/drive/MyDrive/PCVK/WEEK2/IMAGE/basketball.jpg')
img_task7 = cv.cvtColor(new_img7, cv.COLOR_BGR2RGB)
cv.rectangle(img_task7, pt1=(360,150), pt2 =(480,250), color = (255,0,0), thickness = 10)
cv.circle(img_task7, center = (420,200) , radius = 50, color = (0,255,0), thickness = 10)
plt.imshow(img_task7)

# %%
#Tugas 8 
new_img8 = cv.imread('/content/drive/MyDrive/PCVK/WEEK2/IMAGE/kitten01.jpg')
img_task8 = cv.cvtColor(new_img8, cv.COLOR_BGR2RGB)
img_task8[450:,:200,0] = 0
img_task8[450:,:200,1] = 0
plt.imshow(img_task8)

# %%
#Tugas 9
font  = cv.FONT_HERSHEY_TRIPLEX
img_task9 = img_task8.copy()
cv.putText(img_task9, text="Hello...", org=(150,400), fontFace=font, fontScale=2, color =(255,255,0),thickness = 5, lineType = cv.LINE_AA)
plt.imshow(img_task9)
